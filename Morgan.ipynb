# %%
import os
sudoPassword = '2004'
command = 'pip install deepspeech'


p = os.system('echo %s|sudo -S %s' % (sudoPassword, command))

# %%
# !git clone https://github.com/coqui-ai/TTS
# %cd TTS
# !git checkout b1935c97
# !pip install -r requirements.txt
# !python setup.py install
# %cd ..
# Out:
# fatal: destination path 'TTS' already exists and is not an empty directory.
# /home/lazarev/pythonPr/TTS
# HEAD is now at b1935c9 update server to enable native vocoder inference and remove pwgan support
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy>=1.16.0 in /home/lazarev/.local/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (1.17.5)
# Requirement already satisfied: torch>=1.5 in /home/lazarev/.local/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (1.8.1)
# Requirement already satisfied: librosa>=0.5.1 in /home/lazarev/.local/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: Unidecode>=0.4.20 in /home/lazarev/.local/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (0.4.20)
# Requirement already satisfied: tensorboard in /home/lazarev/.local/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (2.4.1)
# Requirement already satisfied: tensorboardX in /home/lazarev/.local/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (2.1)
# Requirement already satisfied: matplotlib in /opt/anaconda/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (3.3.4)
# Requirement already satisfied: Pillow in /opt/anaconda/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (8.1.2)
# Requirement already satisfied: flask in /opt/anaconda/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (1.1.2)
# Requirement already satisfied: scipy in /opt/anaconda/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (1.6.2)
# Requirement already satisfied: tqdm in /opt/anaconda/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (4.59.0)
# Requirement already satisfied: soundfile in /home/lazarev/.local/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (0.10.3.post1)
# Requirement already satisfied: phonemizer in /home/lazarev/.local/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (2.2.2)
# Requirement already satisfied: bokeh==1.4.0 in /home/lazarev/.local/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: packaging>=16.8 in /opt/anaconda/lib/python3.8/site-packages (from bokeh==1.4.0->-r requirements.txt (line 14)) (20.9)
# Requirement already satisfied: Jinja2>=2.7 in /opt/anaconda/lib/python3.8/site-packages (from bokeh==1.4.0->-r requirements.txt (line 14)) (2.11.3)
# Requirement already satisfied: tornado>=4.3 in /opt/anaconda/lib/python3.8/site-packages (from bokeh==1.4.0->-r requirements.txt (line 14)) (6.1)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/anaconda/lib/python3.8/site-packages (from bokeh==1.4.0->-r requirements.txt (line 14)) (2.8.1)
# Requirement already satisfied: six>=1.5.2 in /opt/anaconda/lib/python3.8/site-packages (from bokeh==1.4.0->-r requirements.txt (line 14)) (1.15.0)
# Requirement already satisfied: PyYAML>=3.10 in /opt/anaconda/lib/python3.8/site-packages (from bokeh==1.4.0->-r requirements.txt (line 14)) (5.4.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /opt/anaconda/lib/python3.8/site-packages (from librosa>=0.5.1->-r requirements.txt (line 3)) (0.24.1)
# Requirement already satisfied: resampy>=0.2.2 in /home/lazarev/.local/lib/python3.8/site-packages (from librosa>=0.5.1->-r requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: audioread>=2.0.0 in /home/lazarev/.local/lib/python3.8/site-packages (from librosa>=0.5.1->-r requirements.txt (line 3)) (2.1.9)
# Requirement already satisfied: joblib>=0.12 in /opt/anaconda/lib/python3.8/site-packages (from librosa>=0.5.1->-r requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: numba>=0.43.0 in /home/lazarev/.local/lib/python3.8/site-packages (from librosa>=0.5.1->-r requirements.txt (line 3)) (0.48.0)
# Requirement already satisfied: decorator>=3.0.0 in /opt/anaconda/lib/python3.8/site-packages (from librosa>=0.5.1->-r requirements.txt (line 3)) (4.4.2)
# Requirement already satisfied: cffi>=1.0 in /opt/anaconda/lib/python3.8/site-packages (from soundfile->-r requirements.txt (line 12)) (1.14.5)
# Requirement already satisfied: typing-extensions in /opt/anaconda/lib/python3.8/site-packages (from torch>=1.5->-r requirements.txt (line 2)) (3.7.4.3)
# Requirement already satisfied: pycparser in /opt/anaconda/lib/python3.8/site-packages (from cffi>=1.0->soundfile->-r requirements.txt (line 12)) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda/lib/python3.8/site-packages (from Jinja2>=2.7->bokeh==1.4.0->-r requirements.txt (line 14)) (1.1.1)
# Requirement already satisfied: setuptools in /opt/anaconda/lib/python3.8/site-packages (from numba>=0.43.0->librosa>=0.5.1->-r requirements.txt (line 3)) (52.0.0.post20210125)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /home/lazarev/.local/lib/python3.8/site-packages (from numba>=0.43.0->librosa>=0.5.1->-r requirements.txt (line 3)) (0.31.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda/lib/python3.8/site-packages (from packaging>=16.8->bokeh==1.4.0->-r requirements.txt (line 14)) (2.4.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda/lib/python3.8/site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa>=0.5.1->-r requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in /opt/anaconda/lib/python3.8/site-packages (from flask->-r requirements.txt (line 9)) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in /opt/anaconda/lib/python3.8/site-packages (from flask->-r requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: click>=5.1 in /opt/anaconda/lib/python3.8/site-packages (from flask->-r requirements.txt (line 9)) (7.1.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 7)) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: attrs>=18.1 in /opt/anaconda/lib/python3.8/site-packages (from phonemizer->-r requirements.txt (line 13)) (20.3.0)
# Requirement already satisfied: segments in /home/lazarev/.local/lib/python3.8/site-packages (from phonemizer->-r requirements.txt (line 13)) (2.2.0)
# Requirement already satisfied: wheel>=0.26 in /opt/anaconda/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 5)) (0.36.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/lazarev/.local/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: protobuf>=3.6.0 in /home/lazarev/.local/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 5)) (3.15.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 5)) (2.25.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/lazarev/.local/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 5)) (0.4.3)
# Requirement already satisfied: grpcio>=1.24.3 in /home/lazarev/.local/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 5)) (1.36.1)
# Requirement already satisfied: absl-py>=0.4 in /home/lazarev/.local/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 5)) (0.12.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/lazarev/.local/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 5)) (3.3.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /home/lazarev/.local/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 5)) (1.28.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/lazarev/.local/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard->-r requirements.txt (line 5)) (4.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/lazarev/.local/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard->-r requirements.txt (line 5)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/lazarev/.local/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard->-r requirements.txt (line 5)) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/lazarev/.local/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/lazarev/.local/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard->-r requirements.txt (line 5)) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 5)) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 5)) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 5)) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 5)) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/lazarev/.local/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: clldutils>=1.7.3 in /home/lazarev/.local/lib/python3.8/site-packages (from segments->phonemizer->-r requirements.txt (line 13)) (3.7.0)
# Requirement already satisfied: regex in /opt/anaconda/lib/python3.8/site-packages (from segments->phonemizer->-r requirements.txt (line 13)) (2021.3.17)
# Requirement already satisfied: csvw>=1.5.6 in /home/lazarev/.local/lib/python3.8/site-packages (from segments->phonemizer->-r requirements.txt (line 13)) (1.10.1)
# Requirement already satisfied: tabulate>=0.7.7 in /home/lazarev/.local/lib/python3.8/site-packages (from clldutils>=1.7.3->segments->phonemizer->-r requirements.txt (line 13)) (0.8.9)
# Requirement already satisfied: colorlog in /home/lazarev/.local/lib/python3.8/site-packages (from clldutils>=1.7.3->segments->phonemizer->-r requirements.txt (line 13)) (4.8.0)
# Requirement already satisfied: isodate in /home/lazarev/.local/lib/python3.8/site-packages (from csvw>=1.5.6->segments->phonemizer->-r requirements.txt (line 13)) (0.6.0)
# Requirement already satisfied: rfc3986 in /home/lazarev/.local/lib/python3.8/site-packages (from csvw>=1.5.6->segments->phonemizer->-r requirements.txt (line 13)) (1.4.0)
# Requirement already satisfied: uritemplate>=3.0.0 in /home/lazarev/.local/lib/python3.8/site-packages (from csvw>=1.5.6->segments->phonemizer->-r requirements.txt (line 13)) (3.0.1)
# running install
# error: can't create or remove files in install directory
#
# The following error occurred while trying to add or remove files in the
# installation directory:
#
#     [Errno 13] Permission denied: '/opt/anaconda/lib/python3.8/site-packages/test-easy-install-2791.write-test'
#
# The installation directory you specified (via --install-dir, --prefix, or
# the distutils default setting) was:
#
#     /opt/anaconda/lib/python3.8/site-packages/
#
# Perhaps your account does not have write access to this directory?  If the
# installation directory is a system-owned directory, you may need to sign in
# as the administrator or "root" account.  If you do not have administrative
# access to this machine, you may wish to choose a different installation
# directory, preferably one that is listed in your PYTHONPATH environment
# variable.
#
# For information on other options, you may wish to consult the
# documentation at:
#
#   https://setuptools.readthedocs.io/en/latest/easy_install.html
#
# Please make the appropriate changes for your system and try again.
#
# /home/lazarev/pythonPr

# %%
# !gdown --id 1dntzjWFg7ufWaTaFy80nRz-Tu02xWZos -O tts_model.pth.tar
# !gdown --id 18CQ6G6tBEOfvCHlPqP8EBI4xWbrr9dBc -O config.json
# !gdown --id 1Ty5DZdOc0F7OTGj9oJThYbL5iVu_2G0K -O vocoder_model.pth.tar
# !gdown --id 1Rd0R_nRCrbjEdpOwq6XwZAktvugiBvmu -O config_vocoder.json
# !gdown --id 11oY3Tv0kQtxK_JPgxrfesa99maVXHNxU -O scale_stats.npy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1dntzjWFg7ufWaTaFy80nRz-Tu02xWZos
# To: /home/lazarev/pythonPr/tts_model.pth.tar
# 347MB [00:06, 49.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=18CQ6G6tBEOfvCHlPqP8EBI4xWbrr9dBc
# To: /home/lazarev/pythonPr/config.json
# 100%|██████████████████████████████████████| 9.53k/9.53k [00:00<00:00, 6.32MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Ty5DZdOc0F7OTGj9oJThYbL5iVu_2G0K
# To: /home/lazarev/pythonPr/vocoder_model.pth.tar
# 82.8MB [00:01, 46.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Rd0R_nRCrbjEdpOwq6XwZAktvugiBvmu
# To: /home/lazarev/pythonPr/config_vocoder.json
# 100%|██████████████████████████████████████| 6.76k/6.76k [00:00<00:00, 3.13MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11oY3Tv0kQtxK_JPgxrfesa99maVXHNxU
# To: /home/lazarev/pythonPr/scale_stats.npy
# 100%|██████████████████████████████████████| 10.5k/10.5k [00:00<00:00, 8.98MB/s]

# %%
# import speech_recognition as sr
# print(sr.__version__)
# import os
# from pocketsphinx import LiveSpeech, get_model_path
#
# model_path = get_model_path()
#
# speech = LiveSpeech(
#     verbose=False,
#     sampling_rate=16000,
#     buffer_size=2048,
#     no_search=False,
#     full_utt=False,
#     hmm=os.path.join(model_path, 'en-us'),
#     lm=os.path.join(model_path, 'en-us.lm.bin'),
#     dic=os.path.join(model_path, 'cmudict-en-us.dict')
# )

# for phrase in speech:
#     print(phrase)

# import pyttsx3
# engine = pyttsx3.init()
# rate = engine.getProperty('rate')
# engine.setProperty('rate', rate-100)
# voices = engine.getProperty("voices")
# print(voices)
# engine.setProperty("voice", voices[12].id)
# engine.say('Привет.')
# engine.say('The quick brown fox jumped over the lazy dog. Roah')
# engine.runAndWait()
#%cd pythonPr
#!ls
# !deepspeech --model deepspeech-0.9.3-models.pbmm --scorer deepspeech-0.9.3-models.scorer --audio my_audio_file.wav
# Out:
# Loading model from file deepspeech-0.9.3-models.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# Not found: deepspeech-0.9.3-models.pbmm; No such file or directory
# Traceback (most recent call last):
#   File "/opt/anaconda/bin/deepspeech", line 8, in <module>
#     sys.exit(main())
#   File "/opt/anaconda/lib/python3.8/site-packages/deepspeech/client.py", line 119, in main
#     ds = Model(args.model)
#   File "/opt/anaconda/lib/python3.8/site-packages/deepspeech/__init__.py", line 38, in __init__
#     raise RuntimeError("CreateModel failed with '{}' (0x{:X})".format(deepspeech.impl.ErrorCodeToErrorMessage(status),status))
# RuntimeError: CreateModel failed with 'Failed to initialize memory mapped model.' (0x3000)

# %%
def tts(model, text, CONFIG, use_cuda, ap, use_gl, figures=True):
    t_1 = time.time()
    waveform, alignment, mel_spec, mel_postnet_spec, stop_tokens, inputs = synthesis(model, text, CONFIG, use_cuda, ap,

                                                                                     speaker_id, style_wav=None,
                                                                                     truncated=False,
                                                                                     enable_eos_bos_chars=CONFIG.enable_eos_bos_chars)
    # mel_postnet_spec = ap._denormalize(mel_postnet_spec.T)
    if not use_gl:
        waveform = vocoder_model.inference(torch.FloatTensor(mel_postnet_spec.T).unsqueeze(0))
        waveform = waveform.flatten()
    if use_cuda:
        waveform = waveform.cpu()
    waveform = waveform.numpy()
    rtf = (time.time() - t_1) / (len(waveform) / ap.sample_rate)
    tps = (time.time() - t_1) / len(waveform)
    print(waveform.shape)
    print(" > Run-time: {}".format(time.time() - t_1))
    print(" > Real-time factor: {}".format(rtf))
    print(" > Time per step: {}".format(tps))
    IPython.display.display(IPython.display.Audio(waveform, rate=CONFIG.audio['sample_rate']))
    return alignment, mel_postnet_spec, stop_tokens, waveform


import time

import IPython
import torch
from TTS.utils.generic_utils import setup_model
from TTS.utils.synthesis import synthesis
from TTS.utils.text.symbols import symbols, phonemes
from TTS.utils.audio import AudioProcessor
from TTS.utils.io import load_config

# runtime settings
use_cuda = False

# model paths
TTS_MODEL = "tts_model.pth.tar"
TTS_CONFIG = "config.json"
VOCODER_MODEL = "vocoder_model.pth.tar"
VOCODER_CONFIG = "config_vocoder.json"

# load configs
TTS_CONFIG = load_config(TTS_CONFIG)
VOCODER_CONFIG = load_config(VOCODER_CONFIG)

# load the audio processor
ap = AudioProcessor(**TTS_CONFIG.audio)

# LOAD TTS MODEL
# multi speaker
speaker_id = None
speakers = []

# load the model
num_chars = len(phonemes) if TTS_CONFIG.use_phonemes else len(symbols)
model = setup_model(num_chars, len(speakers), TTS_CONFIG)

# load model state
cp = torch.load(TTS_MODEL, map_location=torch.device('cpu'))

# load the model
model.load_state_dict(cp['model'])
if use_cuda:
    model.cuda()
model.eval()

# set model stepsize
if 'r' in cp:
    model.decoder.set_r(cp['r'])

from TTS.vocoder.utils.generic_utils import setup_generator

# LOAD VOCODER MODEL
vocoder_model = setup_generator(VOCODER_CONFIG)
vocoder_model.load_state_dict(torch.load(VOCODER_MODEL, map_location="cpu")["model"])
vocoder_model.remove_weight_norm()
vocoder_model.inference_padding = 0

ap_vocoder = AudioProcessor(**VOCODER_CONFIG['audio'])
if use_cuda:
    vocoder_model.cuda()
vocoder_model.eval()

sentence = "google"
align, spec, stop_tokens, wav = tts(model, sentence, TTS_CONFIG, use_cuda, ap, use_gl=False, figures=True)
# Out:
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > num_mels:80
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > stats_path:./scale_stats.npy
#  | > hop_length:256
#  | > win_length:1024
#  > Using model: Tacotron2
#  > Generator Model: multiband_melgan_generator
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > num_mels:80
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > stats_path:./scale_stats.npy
#  | > hop_length:256
#  | > win_length:1024
# (13056,)
#  > Run-time: 0.28169679641723633
#  > Real-time factor: 0.4755600465132909
#  > Time per step: 2.1567622966626112e-05
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
